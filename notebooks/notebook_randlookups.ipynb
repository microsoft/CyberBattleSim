# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.

"""Random exploration with credential lookup exploitation (notebook)

This notebooks can be run directly from VSCode, to generate a
traditional Jupyter Notebook to open in your browser
 you can run the VSCode command `Export Currenty Python File As Jupyter Notebook`.
"""

# pylint: disable=invalid-name
# Out:
# 'Random exploration with credential lookup exploitation (notebook)\n\nThis notebooks can be run directly from VSCode, to generate a\ntraditional Jupyter Notebook to open in your browser\n you can run the VSCode command `Export Currenty Python File As Jupyter Notebook`.\n'

# %%
from cyberbattle._env.cyberbattle_env import AttackerGoal
from cyberbattle.agents.baseline.agent_randomcredlookup import CredentialCacheExploiter
import cyberbattle.agents.baseline.learner as learner
import gym
import logging
import sys
import cyberbattle.agents.baseline.plotting as p
import cyberbattle.agents.baseline.agent_wrapper as w
from cyberbattle.agents.baseline.agent_wrapper import Verbosity

# %%
# %matplotlib inline

# %%
logging.basicConfig(stream=sys.stdout, level=logging.ERROR, format="%(levelname)s: %(message)s")

# %%
cyberbattlechain_10 = gym.make('CyberBattleChain-v0', size=10,
                               attacker_goal=AttackerGoal(own_atleast_percent=1.0))

# %%
ep = w.EnvironmentBounds.of_identifiers(
    maximum_total_credentials=12,
    maximum_node_count=12,
    identifiers=cyberbattlechain_10.identifiers
)

iteration_count = 9000
training_episode_count = 50
eval_episode_count = 5

# %%
credexplot = learner.epsilon_greedy_search(
    cyberbattlechain_10,
    learner=CredentialCacheExploiter(),
    environment_properties=ep,
    episode_count=training_episode_count,
    iteration_count=iteration_count,
    epsilon=0.90,
    render=False,
    epsilon_multdecay=0.75,  # 0.999,
    epsilon_minimum=0.01,
    verbosity=Verbosity.Quiet,
    title="Random+CredLookup"
)
# Out:
# ###### Random+CredLookup
# Learning with: episode_count=50,iteration_count=9000,ϵ=0.9,ϵ_min=0.01, ϵ_multdecay=0.75,
#   ## Episode: 1/50 'Random+CredLookup' ϵ=0.9000,
# Episode 1|Iteration 920|reward: 6298.0|last_reward_at:  920|Elapsed Time: 0:00:03||
#   Episode 1 ended at t=920
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/368 (0.05)
#     explore-remote: 20/501 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 65
#   ## Episode: 2/50 'Random+CredLookup' ϵ=0.6750,
# Episode 2|Iteration 914|reward: 6300.0|last_reward_at:  914|Elapsed Time: 0:00:03||
#   Episode 2 ended at t=914
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/364 (0.05)
#     explore-remote: 20/499 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 274
#   ## Episode: 3/50 'Random+CredLookup' ϵ=0.5063,
# Episode 3|Iteration 628|reward: 6288.0|last_reward_at:  628|Elapsed Time: 0:00:02||
#   Episode 3 ended at t=628
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/248 (0.07)
#     explore-remote: 19/330 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 293
#   ## Episode: 4/50 'Random+CredLookup' ϵ=0.3797,
# Episode 4|Iteration 921|reward: 6300.0|last_reward_at:  921|Elapsed Time: 0:00:03||
#   Episode 4 ended at t=921
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/390 (0.05)
#     explore-remote: 20/479 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 566
#   ## Episode: 5/50 'Random+CredLookup' ϵ=0.2848,
# Episode 5|Iteration 448|reward: 6300.0|last_reward_at:  448|Elapsed Time: 0:00:01||
#   Episode 5 ended at t=448
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/169 (0.11)
#     explore-remote: 20/227 (0.08)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 306
#   ## Episode: 6/50 'Random+CredLookup' ϵ=0.2136,
# Episode 6|Iteration 457|reward: 6302.0|last_reward_at:  457|Elapsed Time: 0:00:01||
#   Episode 6 ended at t=457
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/193 (0.10)
#     explore-remote: 20/212 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 344
#   ## Episode: 7/50 'Random+CredLookup' ϵ=0.1602,
# Episode 7|Iteration 497|reward: 6298.0|last_reward_at:  497|Elapsed Time: 0:00:02||
#   Episode 7 ended at t=497
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/196 (0.10)
#     explore-remote: 20/249 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 405
#   ## Episode: 8/50 'Random+CredLookup' ϵ=0.1201,
# Episode 8|Iteration 540|reward: 6282.0|last_reward_at:  540|Elapsed Time: 0:00:01||
#   Episode 8 ended at t=540
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/219 (0.08)
#     explore-remote: 19/272 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 463
#   ## Episode: 9/50 'Random+CredLookup' ϵ=0.0901,
# Episode 9|Iteration 693|reward: 6282.0|last_reward_at:  693|Elapsed Time: 0:00:02||
#   Episode 9 ended at t=693
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/268 (0.07)
#     explore-remote: 18/377 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 625
#   ## Episode: 10/50 'Random+CredLookup' ϵ=0.0676,
# Episode 10|Iteration 535|reward: 6298.0|last_reward_at:  535|Elapsed Time: 0:00:02||
#   Episode 10 ended at t=535
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/192 (0.10)
#     explore-remote: 20/291 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 487
#   ## Episode: 11/50 'Random+CredLookup' ϵ=0.0507,
# Episode 11|Iteration 305|reward: 6268.0|last_reward_at:  305|Elapsed Time: 0:00:00||
#   Episode 11 ended at t=305
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/118 (0.14)
#     explore-remote: 17/140 (0.11)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 276
#   ## Episode: 12/50 'Random+CredLookup' ϵ=0.0380,
# Episode 12|Iteration 610|reward: 6298.0|last_reward_at:  610|Elapsed Time: 0:00:02||
#   Episode 12 ended at t=610
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/250 (0.08)
#     explore-remote: 20/308 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 582
#   ## Episode: 13/50 'Random+CredLookup' ϵ=0.0285,
# Episode 13|Iteration 471|reward: 6292.0|last_reward_at:  471|Elapsed Time: 0:00:01||
#   Episode 13 ended at t=471
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/196 (0.09)
#     explore-remote: 20/224 (0.08)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 448
#   ## Episode: 14/50 'Random+CredLookup' ϵ=0.0214,
# Episode 14|Iteration 878|reward: 6296.0|last_reward_at:  878|Elapsed Time: 0:00:03||
#   Episode 14 ended at t=878
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/343 (0.06)
#     explore-remote: 20/484 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 850
#   ## Episode: 15/50 'Random+CredLookup' ϵ=0.0160,
# Episode 15|Iteration 464|reward: 6292.0|last_reward_at:  464|Elapsed Time: 0:00:01||
#   Episode 15 ended at t=464
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/170 (0.11)
#     explore-remote: 18/244 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 446
#   ## Episode: 16/50 'Random+CredLookup' ϵ=0.0120,
# Episode 16|Iteration 372|reward: 6268.0|last_reward_at:  372|Elapsed Time: 0:00:01||
#   Episode 16 ended at t=372
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 18/136 (0.12)
#     explore-remote: 18/189 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 356
#   ## Episode: 17/50 'Random+CredLookup' ϵ=0.0100,
# Episode 17|Iteration 386|reward: 6296.0|last_reward_at:  386|Elapsed Time: 0:00:01||
#   Episode 17 ended at t=386
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/147 (0.12)
#     explore-remote: 20/188 (0.10)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 369
#   ## Episode: 18/50 'Random+CredLookup' ϵ=0.0100,
# Episode 18|Iteration 435|reward: 6288.0|last_reward_at:  435|Elapsed Time: 0:00:01||
#   Episode 18 ended at t=435
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/183 (0.09)
#     explore-remote: 20/202 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 418
#   ## Episode: 19/50 'Random+CredLookup' ϵ=0.0100,
# Episode 19|Iteration 694|reward: 6298.0|last_reward_at:  694|Elapsed Time: 0:00:03||
#   Episode 19 ended at t=694
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/269 (0.07)
#     explore-remote: 20/373 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 674
#   ## Episode: 20/50 'Random+CredLookup' ϵ=0.0100,
# Episode 20|Iteration 526|reward: 6282.0|last_reward_at:  526|Elapsed Time: 0:00:01||
#   Episode 20 ended at t=526
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/213 (0.08)
#     explore-remote: 19/264 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 512
#   ## Episode: 21/50 'Random+CredLookup' ϵ=0.0100,
# Episode 21|Iteration 400|reward: 6300.0|last_reward_at:  400|Elapsed Time: 0:00:01||
#   Episode 21 ended at t=400
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/157 (0.12)
#     explore-remote: 20/191 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 384
#   ## Episode: 22/50 'Random+CredLookup' ϵ=0.0100,
# Episode 22|Iteration 550|reward: 6280.0|last_reward_at:  550|Elapsed Time: 0:00:01||
#   Episode 22 ended at t=550
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/212 (0.08)
#     explore-remote: 18/290 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 535
#   ## Episode: 23/50 'Random+CredLookup' ϵ=0.0100,
# Episode 23|Iteration 400|reward: 6288.0|last_reward_at:  400|Elapsed Time: 0:00:01||
#   Episode 23 ended at t=400
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/124 (0.13)
#     explore-remote: 20/226 (0.08)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 384
#   ## Episode: 24/50 'Random+CredLookup' ϵ=0.0100,
# Episode 24|Iteration 349|reward: 6280.0|last_reward_at:  349|Elapsed Time: 0:00:01||
#   Episode 24 ended at t=349
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/134 (0.12)
#     explore-remote: 19/166 (0.10)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 336
#   ## Episode: 25/50 'Random+CredLookup' ϵ=0.0100,
# Episode 25|Iteration 510|reward: 6292.0|last_reward_at:  510|Elapsed Time: 0:00:01||
#   Episode 25 ended at t=510
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/189 (0.10)
#     explore-remote: 20/270 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 492
#   ## Episode: 26/50 'Random+CredLookup' ϵ=0.0100,
# Episode 26|Iteration 715|reward: 6300.0|last_reward_at:  715|Elapsed Time: 0:00:03||
#   Episode 26 ended at t=715
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/295 (0.07)
#     explore-remote: 20/368 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 696
#   ## Episode: 27/50 'Random+CredLookup' ϵ=0.0100,
# Episode 27|Iteration 340|reward: 6266.0|last_reward_at:  340|Elapsed Time: 0:00:01||
#   Episode 27 ended at t=340
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 17/134 (0.11)
#     explore-remote: 17/161 (0.10)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 325
#   ## Episode: 28/50 'Random+CredLookup' ϵ=0.0100,
# Episode 28|Iteration 454|reward: 6284.0|last_reward_at:  454|Elapsed Time: 0:00:01||
#   Episode 28 ended at t=454
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/160 (0.11)
#     explore-remote: 18/245 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 437
#   ## Episode: 29/50 'Random+CredLookup' ϵ=0.0100,
# Episode 29|Iteration 270|reward: 6254.0|last_reward_at:  270|Elapsed Time: 0:00:00||
#   Episode 29 ended at t=270
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 17/96 (0.15)
#     explore-remote: 16/130 (0.11)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 257
#   ## Episode: 30/50 'Random+CredLookup' ϵ=0.0100,
# Episode 30|Iteration 627|reward: 6294.0|last_reward_at:  627|Elapsed Time: 0:00:02||
#   Episode 30 ended at t=627
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/255 (0.07)
#     explore-remote: 20/321 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 612
#   ## Episode: 31/50 'Random+CredLookup' ϵ=0.0100,
# Episode 31|Iteration 479|reward: 6292.0|last_reward_at:  479|Elapsed Time: 0:00:01||
#   Episode 31 ended at t=479
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/178 (0.10)
#     explore-remote: 20/250 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 464
#   ## Episode: 32/50 'Random+CredLookup' ϵ=0.0100,
# Episode 32|Iteration 726|reward: 6300.0|last_reward_at:  726|Elapsed Time: 0:00:03||
#   Episode 32 ended at t=726
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/287 (0.07)
#     explore-remote: 20/387 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 708
#   ## Episode: 33/50 'Random+CredLookup' ϵ=0.0100,
# Episode 33|Iteration 337|reward: 6268.0|last_reward_at:  337|Elapsed Time: 0:00:00||
#   Episode 33 ended at t=337
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 18/120 (0.13)
#     explore-remote: 17/171 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 324
#   ## Episode: 34/50 'Random+CredLookup' ϵ=0.0100,
# Episode 34|Iteration 319|reward: 6296.0|last_reward_at:  319|Elapsed Time: 0:00:01||
#   Episode 34 ended at t=319
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/127 (0.14)
#     explore-remote: 20/141 (0.12)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 305
#   ## Episode: 35/50 'Random+CredLookup' ϵ=0.0100,
# Episode 35|Iteration 324|reward: 6292.0|last_reward_at:  324|Elapsed Time: 0:00:01||
#   Episode 35 ended at t=324
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/106 (0.16)
#     explore-remote: 20/167 (0.11)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 310
#   ## Episode: 36/50 'Random+CredLookup' ϵ=0.0100,
# Episode 36|Iteration 516|reward: 6292.0|last_reward_at:  516|Elapsed Time: 0:00:01||
#   Episode 36 ended at t=516
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/188 (0.10)
#     explore-remote: 19/278 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 498
#   ## Episode: 37/50 'Random+CredLookup' ϵ=0.0100,
# Episode 37|Iteration 624|reward: 6286.0|last_reward_at:  624|Elapsed Time: 0:00:02||
#   Episode 37 ended at t=624
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 19/242 (0.07)
#     explore-remote: 20/332 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 609
#   ## Episode: 38/50 'Random+CredLookup' ϵ=0.0100,
# Episode 38|Iteration 513|reward: 6296.0|last_reward_at:  513|Elapsed Time: 0:00:01||
#   Episode 38 ended at t=513
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/203 (0.09)
#     explore-remote: 19/259 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 499
#   ## Episode: 39/50 'Random+CredLookup' ϵ=0.0100,
# Episode 39|Iteration 401|reward: 6292.0|last_reward_at:  401|Elapsed Time: 0:00:01||
#   Episode 39 ended at t=401
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/148 (0.12)
#     explore-remote: 19/203 (0.09)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 388
#   ## Episode: 40/50 'Random+CredLookup' ϵ=0.0100,
# Episode 40|Iteration 734|reward: 6292.0|last_reward_at:  734|Elapsed Time: 0:00:03||
#   Episode 40 ended at t=734
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/289 (0.06)
#     explore-remote: 20/394 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 716
#   ## Episode: 41/50 'Random+CredLookup' ϵ=0.0100,
# Episode 41|Iteration 621|reward: 6298.0|last_reward_at:  621|Elapsed Time: 0:00:02||
#   Episode 41 ended at t=621
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/249 (0.08)
#     explore-remote: 20/320 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 603
#   ## Episode: 42/50 'Random+CredLookup' ϵ=0.0100,
# Episode 42|Iteration 526|reward: 6298.0|last_reward_at:  526|Elapsed Time: 0:00:01||
#   Episode 42 ended at t=526
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/211 (0.09)
#     explore-remote: 20/264 (0.07)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 514
#   ## Episode: 43/50 'Random+CredLookup' ϵ=0.0100,
# Episode 43|Iteration 838|reward: 6290.0|last_reward_at:  838|Elapsed Time: 0:00:02||
#   Episode 43 ended at t=838
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/326 (0.06)
#     explore-remote: 19/462 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 824
#   ## Episode: 44/50 'Random+CredLookup' ϵ=0.0100,
# Episode 44|Iteration 680|reward: 6304.0|last_reward_at:  680|Elapsed Time: 0:00:02||
#   Episode 44 ended at t=680
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/266 (0.07)
#     explore-remote: 20/362 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 663
#   ## Episode: 45/50 'Random+CredLookup' ϵ=0.0100,
# Episode 45|Iteration 420|reward: 6288.0|last_reward_at:  420|Elapsed Time: 0:00:01||
#   Episode 45 ended at t=420
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/149 (0.12)
#     explore-remote: 19/221 (0.08)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 407
#   ## Episode: 46/50 'Random+CredLookup' ϵ=0.0100,
# Episode 46|Iteration 583|reward: 6286.0|last_reward_at:  583|Elapsed Time: 0:00:01||
#   Episode 46 ended at t=583
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/217 (0.08)
#     explore-remote: 19/316 (0.06)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 568
#   ## Episode: 47/50 'Random+CredLookup' ϵ=0.0100,
# Episode 47|Iteration 637|reward: 6298.0|last_reward_at:  637|Elapsed Time: 0:00:02||
#   Episode 47 ended at t=637
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/229 (0.08)
#     explore-remote: 20/356 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 613
#   ## Episode: 48/50 'Random+CredLookup' ϵ=0.0100,
# Episode 48|Iteration 648|reward: 6296.0|last_reward_at:  648|Elapsed Time: 0:00:02||
#   Episode 48 ended at t=648
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/246 (0.08)
#     explore-remote: 20/350 (0.05)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 631
#   ## Episode: 49/50 'Random+CredLookup' ϵ=0.0100,
# Episode 49|Iteration 831|reward: 6296.0|last_reward_at:  831|Elapsed Time: 0:00:02||
#   Episode 49 ended at t=831
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 20/351 (0.05)
#     explore-remote: 20/429 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 810
#   ## Episode: 50/50 'Random+CredLookup' ϵ=0.0100,
# Episode 50|Iteration 975|reward: 6302.0|last_reward_at:  975|Elapsed Time: 0:00:03||
#   Episode 50 ended at t=975
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 21/387 (0.05)
#     explore-remote: 20/536 (0.04)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 11/0 (1.00)
#   exploit deflected to exploration: 954
# simulation ended

# %%
randomlearning_results = learner.epsilon_greedy_search(
    cyberbattlechain_10,
    environment_properties=ep,
    learner=CredentialCacheExploiter(),
    episode_count=eval_episode_count,
    iteration_count=iteration_count,
    epsilon=1.0,  # purely random
    render=False,
    verbosity=Verbosity.Quiet,
    title="Random search"
)
# Out:
# ###### Random search
# Learning with: episode_count=5,iteration_count=9000,ϵ=1.0,ϵ_min=0.0,
#   ## Episode: 1/5 'Random search' ϵ=1.0000,
# Episode 1|Iteration 9000|reward:   20.0|last_reward_at:   11|Elapsed Time: 0:00:06||
#   Episode 1 stopped at t=9000
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1500 (0.00)
#     explore-remote: 2/7497 (0.00)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 2/5 'Random search' ϵ=1.0000,
# Episode 2|Iteration 9000|reward:   20.0|last_reward_at:   15|Elapsed Time: 0:00:06||
#   Episode 2 stopped at t=9000
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1497 (0.00)
#     explore-remote: 2/7500 (0.00)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 3/5 'Random search' ϵ=1.0000,
# Episode 3|Iteration 9000|reward:   20.0|last_reward_at:   10|Elapsed Time: 0:00:06||
#   Episode 3 stopped at t=9000
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1484 (0.00)
#     explore-remote: 2/7513 (0.00)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 4/5 'Random search' ϵ=1.0000,
# Episode 4|Iteration 9000|reward:   20.0|last_reward_at:   11|Elapsed Time: 0:00:06||
#   Episode 4 stopped at t=9000
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1560 (0.00)
#     explore-remote: 2/7437 (0.00)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
#   ## Episode: 5/5 'Random search' ϵ=1.0000,
# Episode 5|Iteration 9000|reward:   20.0|last_reward_at:   28|Elapsed Time: 0:00:06||
#   Episode 5 stopped at t=9000
#   Breakdown [Reward/NoReward (Success rate)]
#     explore-local: 1/1481 (0.00)
#     explore-remote: 2/7516 (0.00)
#     explore-connect: 0/0 (NaN)
#     exploit-local: 0/0 (NaN)
#     exploit-remote: 0/0 (NaN)
#     exploit-connect: 0/0 (NaN)
#   exploit deflected to exploration: 0
# simulation ended

# %%
p.plot_episodes_length([credexplot])

p.plot_all_episodes(credexplot)

all_runs = [credexplot,
            randomlearning_results
            ]
p.plot_averaged_cummulative_rewards(
    title=f'Benchmark -- max_nodes={ep.maximum_node_count}, episodes={eval_episode_count},\n',
    all_runs=all_runs)
